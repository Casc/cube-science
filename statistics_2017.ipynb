# %%
import platform
print('Python: ' + platform.python_version())

import numpy as np
print('numpy: ' + np.__version__)

import pandas as pd
print('pandas: ' + pd.__version__)

import matplotlib as plt
print('matplotlib: ' + plt.__version__)
# Out:
# Python: 2.7.9
# numpy: 1.13.0
# pandas: 0.20.2
# matplotlib: 2.0.2

# %%
def loadDecks(filename):
    data = pd.read_json('data/decks/'+filename)
    #print 'Draft number: '+data['draft'][0]
    return data['cards']

def getOneDraftPlayed(decks):
    played = []
    for i in decks:
        for j in i:
            played.append(j)
    return played
    
#loadDecks('decklists_17_8.json')

#print len(getOneDraftPlayed(loadDecks('decklists_17_8.json')))

all_drafts = []
for i in range(1, 8):
    all_drafts.append(set(getOneDraftPlayed(loadDecks('decklists_17_'+str(i)+'.json'))))
    
start_set = all_drafts[0]
for i in range(1, 7):
    start_set = start_set & all_drafts[i]
    print start_set
    if len(start_set) == 0: break
# Out:
# set([u'Glen Elendra Archmage', u'Flames of the Firebrand', u'Garruk Relentless', u'Mutavault', u'Lone Missionary', u'Acidic Slime', u'Triskelion', u'Den Protector', u'Emrakul, the Promised End', u'Sword of Body and Mind', u"Elspeth, Sun's Champion", u'Plow Under', u'Stoneforge Mystic', u'Flame Slash', u'Skullclamp', u'Creeping Tar Pit', u'Terramorphic Expanse', u'Solemn Simulacrum', u'Treasure Cruise', u'Gilded Lotus', u'Bloodstained Mire', u'Oracle of Mul Daya', u'Young Pyromancer', u'Strip Mine', u'Baneslayer Angel', u'Custodi Lich', u'Char', u'Batterskull', u'Sword of Feast and Famine', u'Thran Dynamo', u'Windswept Heath', u'Magus of the Wheel', u'Wooded Bastion'])
# set([u'Lone Missionary', u'Strip Mine', u'Acidic Slime', u'Batterskull', u'Windswept Heath', u"Elspeth, Sun's Champion", u'Plow Under'])
# set([u'Acidic Slime'])
# set([])

# %%
#Check cards popularity

played_dict = {}

for i in all_drafts:
    tmp = list(i)
    for i in tmp:
        if played_dict.has_key(i):
            played_dict[i] +=1
        else:
            played_dict[i] = 1

print len(played_dict)

max_played = 0
max_played_card = ""

for i in played_dict:
    if played_dict[i] > max_played:
        print i, played_dict[i]
        max_played = played_dict[i]
        max_played_card = i
        
for i in range(3, 6):
    print '\nNumber of times played: '+str(i)
    for j in played_dict:
        if played_dict[j] == i:
            print j
# Out:
# 453
# Snuff Out 2
# Polluted Delta 3
# Goblin Rabblemaster 4
# Batterskull 5
#
# Number of times played: 3
# Polluted Delta
# Regrowth
# Aerial Responder
# Pithing Needle
# Glen Elendra Archmage
# Vampiric Tutor
# Garruk, Primal Hunter
# Recurring Nightmare
# Scavenging Ooze
# Counterspell
# Baleful Strix
# Mimic Vat
# Memory Lapse
# Goblin Glory Chaser
# Show and Tell
# Scattered Groves
# Asylum Visitor
# Venser, Shaper Savant
# Kytheon, Hero of Akros
# Jungle Lion
# Heir of Falkenrath
# Ophiomancer
# Mulldrifter
# Elspeth Tirel
# Emrakul, the Promised End
# Wall of Roots
# Fleetwheel Cruiser
# Garruk Relentless
# Maze of Ith
# Bloodstained Mire
# Magus of the Wheel
# Battlefield Forge
# Magma Jet
# Lotus Cobra
# Release the Gremlins
# Solemn Simulacrum
# Courser of Kruphix
# Treasure Cruise
# Recruiter of the Guard
# Firestorm
# Dread Wanderer
# Triskelion
# Karn Liberated
# Nekrataal
# Serum Visions
# Firedrinker Satyr
# Fire // Ice
# Sword of Fire and Ice
# Spear of Heliod
# Awakening Zone
# Llanowar Elves
# Baneslayer Angel
# Custodi Lich
# Trueheart Duelist
# Uktabi Orangutan
# Glory-Bound Initiate
# Dance of the Dead
# Profane Command
# Ajani Goldmane
# Liliana, Heretical Healer
# Master of the Wild Hunt
# Shivan Reef
# Demonic Tutor
# Man-o'-War
# Angel of Invention
# Martial Coup
# Sarkhan, the Dragonspeaker
# Lightning Helix
# Terminate
# Talisman of Impulse
# Mother of Runes
# Hazoret the Fervent
# Figure of Destiny
# Grafted Wargear
# Kor Sanctifiers
# Preordain
# Deranged Hermit
# Brimaz, King of Oreskos
# Dismember
# Gideon Jura
# Animate Dead
# Young Pyromancer
# Warden of the First Tree
# Bribery
# Sorin, Lord of Innistrad
#
# Number of times played: 4
# Goblin Rabblemaster
# Lone Missionary
# Seal of Cleansing
# Acidic Slime
# Strip Mine
# Blade Splicer
# Fyndhorn Elves
# Song of the Dryads
# Terramorphic Expanse
# Powder Keg
# Flame Slash
# Miscalculation
# Psionic Blast
# Char
# Sigarda, Host of Herons
# Manglehorn
# Skullclamp
# Ruinous Path
# Gemstone Mine
# Shriekmaw
# Manic Vandal
# Bonesplitter
# Wooded Bastion
# Swords to Plowshares
# Elspeth, Knight-Errant
# Lightning Bolt
# Oblivion Ring
# Mutavault
# Journey to Nowhere
# Go for the Throat
# Creeping Tar Pit
# Sword of Body and Mind
# Den Protector
# Sun Titan
# Windswept Heath
# Elspeth, Sun's Champion
# Thragtusk
# Balance
# Wild Nacatl
# Stoneforge Mystic
# Polukranos, World Eater
#
# Number of times played: 5
# Batterskull
# Icy Manipulator
# Mind Twist
# Hangarback Walker
# Plow Under
# Kodama's Reach
# Primeval Titan
# Lightning Strike

# %%
# Check archetypes

def loadDecks(filename):
    data = pd.read_json('data/decks/'+filename)
    #print 'Draft number: '+data['draft'][0]
    return data['name']

def getArchetypesDraft(names):
    tmp = []
    for i in names: tmp.append(i)
    return tmp
    

archetypes = loadDecks('decklists_17_8.json')

all_archetypes = []
for i in range(1, 9):
    all_archetypes.append(set(getArchetypesDraft(loadDecks('decklists_17_'+str(i)+'.json'))))
        
archetypes_dict = {}

for i in all_archetypes:
    tmp = list(i)
    for i in tmp:
        if archetypes_dict.has_key(i):
            archetypes_dict[i] +=1
        else:
            archetypes_dict[i] = 1

#print len(archetypes_dict)

max_archetypes = 0
max_played_archetype = ""

for i in archetypes_dict:
    if archetypes_dict[i] > max_archetypes:
        #print i, archetypes_dict[i]
        max_archetype = archetypes_dict[i]
        max_played_archetype = i
        
for i in range(1, 5):
    print '\nNumber of times played: '+str(i)
    for j in archetypes_dict:
        if archetypes_dict[j] == i:
            print j
# Out:
# Number of times played: 1
# RG Aggro
# WB Ramp
# UG Control
# UB Control
# Bant Mid-Range
# WB Control
# Grixis Control
# UGR Control
# BG Mid-Range
# WG Mid-Range
# UBRG Control
# Grixis Ramp
# G Ramp
# WR Mid-Range
# WUBG Ramp
# Boros Aggro
# Jund Mid-Range
#
# Number of times played: 2
# UW Control
# Naya Aggro
# BR Aggro
# WR Aggro
# WB Aggro
# UB Mid-Range
# UR Aggro
#
# Number of times played: 3
# WG Aggro
#
# Number of times played: 4
# WG Ramp

# %%
# Check players

def loadDecks(filename):
    data = pd.read_json('data/decks/'+filename)
    #print 'Draft number: '+data['draft'][0]
    return data['player']

def getPlayersDraft(players):
    tmp = []
    for i in players: tmp.append(i)
    return tmp
    

players = loadDecks('decklists_17_8.json')

all_players = []
for i in range(1, 9):
    all_players.append(set(getPlayersDraft(loadDecks('decklists_17_'+str(i)+'.json'))))
        
players_dict = {}

for i in all_players:
    tmp = list(i)
    for i in tmp:
        if players_dict.has_key(i):
            players_dict[i] +=1
        else:
            players_dict[i] = 1

#print len(archetypes_dict)

max_players = 0
max_played_player = ""

for i in players_dict:
    if players_dict[i] > max_players:
        #print i, archetypes_dict[i]
        max_players = players_dict[i]
        max_played_player = i
        
for i in range(1, 9):
    print '\nNumber of times played: '+str(i)
    for j in players_dict:
        if players_dict[j] == i:
            print j
# Out:
# Number of times played: 1
# Marek
# TomekD
# SirK
# Suld
#
# Number of times played: 2
#
# Number of times played: 3
# Mateusz
# TomekP
# Kasia
# Wielki
#
# Number of times played: 4
# Wojtek
# Kuba
#
# Number of times played: 5
#
# Number of times played: 6
#
# Number of times played: 7
# Bartek
#
# Number of times played: 8
# Casc

# %% [markdown]
# **Players win %**

# %%
# players win %

# %%
def loadMatches(filename):
    matches = pd.read_json('data/matches/'+filename)
    match_data = []
    for i in matches["matches"]: 
        record = []
        record.append({"player": i[0]["player"], "score": i[0]["score"]})
        record.append({"player": i[1]["player"], "score": i[1]["score"]})
        match_data.append(record)
    return match_data

def loadAllMatchesFromYear(number_of_drafts, yy):
    match_data = []
    for i in range(1, number_of_drafts+1):
        tmp = loadMatches('matches_'+str(yy)+'_'+str(i)+'.json')
        for j in tmp:
            match_data.append(j)
    return match_data
        
all_matches = loadAllMatchesFromYear(8, 17)
print(len(all_matches))

def extract_players(my_matches):
    players = []
    for i in my_matches:
        players.append(i[0]["player"])
        players.append(i[1]["player"])
    return list(set(players))

def getWinRatioForPlayer(player, matches):
    player_matches = []
    won, lost, m_won, m_lost, total, m_total = 0, 0, 0, 0, 0, 0 
    for i in matches:
        if i[0]['player'] == player or i[1]['player'] == player:
            player_matches.append(i)
    m_total = len(player_matches)
    
    for i in player_matches:
        if i[0]['player'] == player:
            won += i[0]['score']
            lost += i[1]['score']
            if i[0]['score'] > i[1]['score']: m_won +=1
            else: m_lost +=1
        if i[1]['player'] == player:
            won += i[1]['score']
            lost += i[0]['score']
            if i[1]['score'] > i[0]['score']: m_won +=1
            else: m_lost +=1
    total = won+lost
    
    win_rate_games = 100*round((won+0.0)/total, 4)
    win_rate_matches = 100*round((m_won+0.0)/m_total, 4)
    alpha_factor = round(win_rate_matches - win_rate_games, 4)
    
    return {'player': player,
           'won': won,
           'lost': lost,
           'matches_won': m_won,
           'matches_lost': m_lost,
           'total': total,
           'matches_total': m_total,
           'win_rate_games':win_rate_games,
           'win_rate_matches':win_rate_matches, 
           'alpha_factor':alpha_factor }
          
all_players = extract_players(all_matches)

for player in all_players:
    print(getWinRatioForPlayer(player, all_matches))
# Out:
# 81
# {'player': u'Marek', 'alpha_factor': -25.0, 'won': 4, 'matches_total': 6, 'lost': 12, 'matches_won': 0, 'matches_lost': 6, 'total': 16, 'win_rate_games': 25.0, 'win_rate_matches': 0.0}
# {'player': u'TomekD', 'alpha_factor': 22.86, 'won': 8, 'matches_total': 5, 'lost': 6, 'matches_won': 4, 'matches_lost': 1, 'total': 14, 'win_rate_games': 57.14, 'win_rate_matches': 80.0}
# {'player': u'Casc', 'alpha_factor': 3.34, 'won': 51, 'matches_total': 31, 'lost': 37, 'matches_won': 19, 'matches_lost': 12, 'total': 88, 'win_rate_games': 57.95, 'win_rate_matches': 61.29}
# {'player': u'SirK', 'alpha_factor': 14.58, 'won': 11, 'matches_total': 6, 'lost': 5, 'matches_won': 5, 'matches_lost': 1, 'total': 16, 'win_rate_games': 68.75, 'win_rate_matches': 83.33}
# {'player': u'Mateusz', 'alpha_factor': -4.6, 'won': 11, 'matches_total': 12, 'lost': 18, 'matches_won': 4, 'matches_lost': 8, 'total': 29, 'win_rate_games': 37.93, 'win_rate_matches': 33.33}
# {'player': u'TomekP', 'alpha_factor': -4.4, 'won': 15, 'matches_total': 13, 'lost': 20, 'matches_won': 5, 'matches_lost': 8, 'total': 35, 'win_rate_games': 42.86, 'win_rate_matches': 38.46}
# {'player': u'Suld', 'alpha_factor': -1.67, 'won': 5, 'matches_total': 5, 'lost': 7, 'matches_won': 2, 'matches_lost': 3, 'total': 12, 'win_rate_games': 41.67, 'win_rate_matches': 40.0}
# {'player': u'Kasia', 'alpha_factor': -9.82, 'won': 10, 'matches_total': 14, 'lost': 22, 'matches_won': 3, 'matches_lost': 11, 'total': 32, 'win_rate_games': 31.25, 'win_rate_matches': 21.43}
# {'player': u'Wojtek', 'alpha_factor': 1.02, 'won': 27, 'matches_total': 17, 'lost': 25, 'matches_won': 9, 'matches_lost': 8, 'total': 52, 'win_rate_games': 51.92, 'win_rate_matches': 52.94}
# {'player': u'Kuba', 'alpha_factor': 9.09, 'won': 29, 'matches_total': 16, 'lost': 15, 'matches_won': 12, 'matches_lost': 4, 'total': 44, 'win_rate_games': 65.91, 'win_rate_matches': 75.0}
# {'player': u'Wielki', 'alpha_factor': -7.76, 'won': 15, 'matches_total': 11, 'lost': 19, 'matches_won': 4, 'matches_lost': 7, 'total': 34, 'win_rate_games': 44.12, 'win_rate_matches': 36.36}
# {'player': u'Bartek', 'alpha_factor': 3.85, 'won': 38, 'matches_total': 26, 'lost': 38, 'matches_won': 14, 'matches_lost': 12, 'total': 76, 'win_rate_games': 50.0, 'win_rate_matches': 53.849999999999994}

# %% [markdown]
# **Add scores to the decks**

# %%
# load matches and decklists for specific draft

class deck:
    def __init__(self, player, player_stats, draft, cards, name):
        self.player = player
        self.player_stats = player_stats
        self.name = name
        self.draft = draft
        self.cards = cards
        tmp = name.split(' ')
        self.colors = tmp[0]
        self.type = tmp[1] 

def loadDrafts(filename):
    draft_data = pd.read_json('data/decks/'+filename)
    return draft_data

def loadMatchData(filename):
    match_data = pd.read_json('data/matches/'+filename)
    return match_data

def loadDraftData(draft_number, yy):
    filename_matches = 'matches_'+str(yy)+'_'+str(draft_number)+'.json'
    filename_decks = 'decklists_'+str(yy)+'_'+str(draft_number)+'.json'
    match_data = loadMatchData(filename_matches)
    deck_data = loadDrafts(filename_decks)
    decks = []
    
    for i in range(0, len(deck_data)):
        decks.append(deck(deck_data['player'][i], getWinRatioForPlayer(deck_data['player'][i], match_data['matches']),
                    deck_data['draft'][i], deck_data['cards'][i], deck_data['name'][i]) )
        
    return decks
    
def loadAllDraftDataYear(number_of_drafts, yy):
    all_decks = []
    for i in range(1, number_of_drafts+1):
        tmp = loadDraftData(i, yy)
        for j in tmp:
            all_decks.append(j)
    return all_decks
    
all_decks = loadAllDraftDataYear(8, 17)

# %%
# Calculate colors and archetypes win rates

def getColorsDict(all_decks):
    colors_dict = {}
    for i in all_decks:
        if colors_dict.has_key(i.colors):
            colors_dict[i.colors] +=1
        else:
            colors_dict[i.colors] =1
    return colors_dict

def getArchetypesDict(all_decks):
    archetypes_dict = {}
    for i in all_decks:
        if archetypes_dict.has_key(i.type):
            archetypes_dict[i.type] +=1
        else:
            archetypes_dict[i.type] =1 
    return archetypes_dict

def getArchetypeWinRate(decks, archetype):
    won, lost, m_won, m_lost, total, m_total = 0, 0, 0, 0, 0, 0
    for i in decks:
        if (i.type == archetype):
            won +=i.player_stats['won']
            lost +=i.player_stats['lost']
            m_won +=i.player_stats['matches_won']
            m_lost +=i.player_stats['matches_lost']
            total +=i.player_stats['total']
            m_total +=i.player_stats['matches_total']
            
    win_rate_games = 100*round((won+0.0)/total, 4)
    win_rate_matches = 100*round((m_won+0.0)/m_total, 4)
    alpha_factor = round(win_rate_matches - win_rate_games, 4)
    return {'type': archetype,
           'won': won,
           'lost': lost,
           'matches_won': m_won,
           'matches_lost': m_lost,
           'total': total,
           'matches_total': m_total,
           'win_rate_games':win_rate_games,
           'win_rate_matches': win_rate_matches, 
           'alpha_factor':alpha_factor }
    
def getArchetypesWinRate(decks):
    archetypes = getArchetypesDict(decks)
    for i in archetypes:
        print(getArchetypeWinRate(decks, i))

#getArchetypesWinRate(all_decks)

def getColorWinRate(decks, color):
    won, lost, m_won, m_lost, total, m_total = 0, 0, 0, 0, 0, 0
    for i in decks:
        if (i.colors == color):
            won +=i.player_stats['won']
            lost +=i.player_stats['lost']
            m_won +=i.player_stats['matches_won']
            m_lost +=i.player_stats['matches_lost']
            total +=i.player_stats['total']
            m_total +=i.player_stats['matches_total']
            
    win_rate_games = 100*round((won+0.0)/total, 4)
    win_rate_matches = 100*round((m_won+0.0)/m_total, 4)
    alpha_factor = round(win_rate_matches - win_rate_games, 4)
    return {'colors': color,
           'won': won,
           'lost': lost,
           'matches_won': m_won,
           'matches_lost': m_lost,
           'total': total,
           'matches_total': m_total,
           'win_rate_games':win_rate_games,
           'win_rate_matches': win_rate_matches, 
           'alpha_factor':alpha_factor }
    
def getColorsWinRate(decks):
    colors = getColorsDict(decks)
    for i in colors:
        print '\n'+i
        print(getColorWinRate(decks, i))
        
getColorsWinRate(all_decks)
# Out:
# WG
# {'alpha_factor': 2.22, 'matches_won': 18, 'colors': u'WG', 'won': 43, 'matches_total': 36, 'lost': 47, 'win_rate_matches': 50.0, 'matches_lost': 18, 'total': 90, 'win_rate_games': 47.78}
#
# Bant
# {'alpha_factor': -18.18, 'matches_won': 0, 'colors': u'Bant', 'won': 2, 'matches_total': 3, 'lost': 9, 'win_rate_matches': 0.0, 'matches_lost': 3, 'total': 11, 'win_rate_games': 18.18}
#
# BG
# {'alpha_factor': 13.71, 'matches_won': 9, 'colors': u'BG', 'won': 19, 'matches_total': 12, 'lost': 12, 'win_rate_matches': 75.0, 'matches_lost': 3, 'total': 31, 'win_rate_games': 61.29}
#
# WB
# {'alpha_factor': -12.36, 'matches_won': 3, 'colors': u'WB', 'won': 14, 'matches_total': 16, 'lost': 31, 'win_rate_matches': 18.75, 'matches_lost': 13, 'total': 45, 'win_rate_games': 31.11}
#
# G
# {'alpha_factor': -16.67, 'matches_won': 1, 'colors': u'G', 'won': 4, 'matches_total': 3, 'lost': 4, 'win_rate_matches': 33.33, 'matches_lost': 2, 'total': 8, 'win_rate_games': 50.0}
#
# WUBG
# {'alpha_factor': -6.15, 'matches_won': 2, 'colors': u'WUBG', 'won': 6, 'matches_total': 5, 'lost': 7, 'win_rate_matches': 40.0, 'matches_lost': 3, 'total': 13, 'win_rate_games': 46.150000000000006}
#
# Boros
# {'alpha_factor': 25.0, 'matches_won': 3, 'colors': u'Boros', 'won': 6, 'matches_total': 3, 'lost': 2, 'win_rate_matches': 100.0, 'matches_lost': 0, 'total': 8, 'win_rate_games': 75.0}
#
# UBRG
# {'alpha_factor': 11.11, 'matches_won': 2, 'colors': u'UBRG', 'won': 5, 'matches_total': 3, 'lost': 4, 'win_rate_matches': 66.67, 'matches_lost': 1, 'total': 9, 'win_rate_games': 55.559999999999995}
#
# Naya
# {'alpha_factor': 2.38, 'matches_won': 3, 'colors': u'Naya', 'won': 10, 'matches_total': 6, 'lost': 11, 'win_rate_matches': 50.0, 'matches_lost': 3, 'total': 21, 'win_rate_games': 47.620000000000005}
#
# UR
# {'alpha_factor': -6.4, 'matches_won': 5, 'colors': u'UR', 'won': 14, 'matches_total': 11, 'lost': 13, 'win_rate_matches': 45.45, 'matches_lost': 6, 'total': 27, 'win_rate_games': 51.849999999999994}
#
# Grixis
# {'alpha_factor': -26.19, 'matches_won': 1, 'colors': u'Grixis', 'won': 9, 'matches_total': 6, 'lost': 12, 'win_rate_matches': 16.669999999999998, 'matches_lost': 5, 'total': 21, 'win_rate_games': 42.86}
#
# RG
# {'alpha_factor': 18.18, 'matches_won': 3, 'colors': u'RG', 'won': 9, 'matches_total': 3, 'lost': 2, 'win_rate_matches': 100.0, 'matches_lost': 0, 'total': 11, 'win_rate_games': 81.82000000000001}
#
# Jund
# {'alpha_factor': -14.29, 'matches_won': 0, 'colors': u'Jund', 'won': 1, 'matches_total': 3, 'lost': 6, 'win_rate_matches': 0.0, 'matches_lost': 3, 'total': 7, 'win_rate_games': 14.29}
#
# BR
# {'alpha_factor': 0.7, 'matches_won': 6, 'colors': u'BR', 'won': 14, 'matches_total': 11, 'lost': 12, 'win_rate_matches': 54.55, 'matches_lost': 5, 'total': 26, 'win_rate_games': 53.849999999999994}
#
# UGR
# {'alpha_factor': 12.12, 'matches_won': 2, 'colors': u'UGR', 'won': 6, 'matches_total': 3, 'lost': 5, 'win_rate_matches': 66.67, 'matches_lost': 1, 'total': 11, 'win_rate_games': 54.55}
#
# UG
# {'alpha_factor': 22.86, 'matches_won': 4, 'colors': u'UG', 'won': 8, 'matches_total': 5, 'lost': 6, 'win_rate_matches': 80.0, 'matches_lost': 1, 'total': 14, 'win_rate_games': 57.14}
#
# WR
# {'alpha_factor': -9.52, 'matches_won': 6, 'colors': u'WR', 'won': 22, 'matches_total': 14, 'lost': 20, 'win_rate_matches': 42.86, 'matches_lost': 8, 'total': 42, 'win_rate_games': 52.38}
#
# UW
# {'alpha_factor': 6.67, 'matches_won': 4, 'colors': u'UW', 'won': 9, 'matches_total': 6, 'lost': 6, 'win_rate_matches': 66.67, 'matches_lost': 2, 'total': 15, 'win_rate_games': 60.0}
#
# UB
# {'alpha_factor': 8.7, 'matches_won': 9, 'colors': u'UB', 'won': 23, 'matches_total': 13, 'lost': 15, 'win_rate_matches': 69.23, 'matches_lost': 4, 'total': 38, 'win_rate_games': 60.529999999999994}

# %%
# Card win rates

def getCardsDict(decks):
    card_dict = {}
    for i in decks:
        for j in i.cards:
            if card_dict.has_key(j):
                card_dict[j]['won']+=i.player_stats['won']
                card_dict[j]['lost']+=i.player_stats['lost']
                card_dict[j]['matches_won']+=i.player_stats['matches_won']
                card_dict[j]['matches_lost']+=i.player_stats['matches_lost']
                card_dict[j]['total']+=i.player_stats['total']
                card_dict[j]['matches_total']+=i.player_stats['matches_total']
            else:
                card_dict[j] = {'won': i.player_stats['won'], 
                                'lost': i.player_stats['lost'],
                                'matches_won':i.player_stats['matches_won'],
                                'matches_lost':i.player_stats['matches_lost'],
                                'total':i.player_stats['total'],
                                'matches_total':i.player_stats['matches_total']
                               }
                
    cards_games_won = []
    cards_matches_won = []
    for i in card_dict: 
        win_rate_games = 100*round((card_dict[i]['won']+0.0)/card_dict[i]['total'], 4)
        win_rate_matches = 100*round((card_dict[i]['matches_won']+0.0)/card_dict[i]['matches_total'], 4)
        alpha_factor = round(win_rate_matches - win_rate_games, 4)
        if card_dict[i]['total'] >=15:
            cards_games_won.append((i, win_rate_games))
            cards_matches_won.append((i, win_rate_matches))
            
    cards_games_won = reversed(sorted(cards_games_won, key=lambda x: x[1]))
    cards_matches_won = reversed(sorted(cards_matches_won, key=lambda x: x[1]))

    return cards_games_won, cards_matches_won
    
    
card_games_win, card_matches_win = getCardsDict(all_decks)

for i in card_games_win: print i
# Out:
# (u'Searing Spear', 84.21)
# (u'Soul-Scar Mage', 78.95)
# (u'Hellrider', 78.95)
# (u'Arcane Denial', 77.78)
# (u'Meloku the Clouded Mirror', 77.78)
# (u'Ancestral Vision', 75.0)
# (u'Noose Constrictor', 74.07000000000001)
# (u'Sylvan Caryatid', 73.91)
# (u'Stromkirk Noble', 73.08)
# (u'Morphling', 72.72999999999999)
# (u'Vedalken Shackles', 72.72999999999999)
# (u'Rancor', 72.22)
# (u'Phantasmal Image', 72.0)
# (u'Evolving Wilds', 70.0)
# (u'Coldsteel Heart', 69.23)
# (u'Snuff Out', 69.23)
# (u'Heir of Falkenrath', 69.05)
# (u'Living Death', 68.97)
# (u'Sylvan Library', 68.75)
# (u'Diregraf Ghoul', 68.75)
# (u'Hissing Quagmire', 68.75)
# (u'Never // Return', 68.75)
# (u'Eternal Witness', 68.75)
# (u"Umezawa's Jitte", 68.75)
# (u'Psionic Blast', 68.42)
# (u'Troll Ascetic', 68.0)
# (u'Shivan Reef', 67.74)
# (u'Boros Charm', 66.67)
# (u'Burst Lightning', 66.67)
# (u'Zealous Conscripts', 66.67)
# (u'Boros Signet', 66.67)
# (u'Sword of Light and Shadow', 66.67)
# (u'Thundermaw Hellkite', 66.67)
# (u'Flametongue Kavu', 66.67)
# (u'Sundering Titan', 66.67)
# (u"Smuggler's Copter", 66.67)
# (u'Sword of War and Peace', 66.67)
# (u'Breeding Pool', 66.67)
# (u'Rugged Prairie', 66.67)
# (u'Lightning Bolt', 66.10000000000001)
# (u'Deranged Hermit', 65.52)
# (u'Den Protector', 65.52)
# (u'Courser of Kruphix', 65.22)
# (u'Pia Nalaar', 64.52)
# (u'Fleetwheel Cruiser', 64.52)
# (u'Venser, Shaper Savant', 64.29)
# (u'Lightning Greaves', 64.1)
# (u'Battlefield Forge', 63.89)
# (u'Emrakul, the Promised End', 63.63999999999999)
# (u'Dismember', 63.41)
# (u'Scrapheap Scrounger', 63.33)
# (u'Deathrite Shaman', 63.33)
# (u'Flooded Strand', 63.160000000000004)
# (u'Nimble Obstructionist', 62.96000000000001)
# (u'Smash to Smithereens', 62.86000000000001)
# (u'Mulldrifter', 62.86000000000001)
# (u'Kessig Prowler', 62.5)
# (u'Miscalculation', 62.07)
# (u'Koth of the Hammer', 61.9)
# (u'Inferno Titan', 61.9)
# (u'Bloodsoaked Champion', 61.53999999999999)
# (u'Necromancy', 61.53999999999999)
# (u"Chainer's Edict", 61.53999999999999)
# (u'Talisman of Impulse', 61.29)
# (u'Glory-Bound Initiate', 61.11)
# (u"Elspeth, Sun's Champion", 60.980000000000004)
# (u'Lightning Helix', 60.709999999999994)
# (u'Baleful Strix', 60.529999999999994)
# (u'Gilded Lotus', 60.0)
# (u'Exclude', 60.0)
# (u'Figure of Destiny', 60.0)
# (u'Hedron Archive', 60.0)
# (u'Thran Dynamo', 60.0)
# (u'Bloodbraid Elf', 60.0)
# (u'Oracle of Mul Daya', 60.0)
# (u'Abbot of Keral Keep', 60.0)
# (u'Lotus Cobra', 59.46)
# (u'Sword of Feast and Famine', 59.38)
# (u'Magus of the Wheel', 59.38)
# (u'Forbid', 59.089999999999996)
# (u'Strip Mine', 59.089999999999996)
# (u'Dance of the Dead', 58.97)
# (u'City of Brass', 58.620000000000005)
# (u'Gideon Jura', 58.540000000000006)
# (u'Baneslayer Angel', 58.330000000000005)
# (u'Trueheart Duelist', 58.06)
# (u'Shriekmaw', 57.69)
# (u'Porcelain Legionnaire', 57.58)
# (u'Animate Dead', 57.410000000000004)
# (u'Profane Command', 57.410000000000004)
# (u'Warden of the First Tree', 57.14)
# (u'Wrath of God', 57.14)
# (u'Wasteland', 57.14)
# (u'Kor Sanctifiers', 56.76)
# (u'Nissa, Steward of Elements', 56.52)
# (u'Remand', 56.52)
# (u'Bribery', 56.25)
# (u'Stratus Dancer', 56.25)
# (u'Sigarda, Host of Herons', 56.10000000000001)
# (u'Force Spike', 56.00000000000001)
# (u'Phyrexian Revoker', 56.00000000000001)
# (u'Batterskull', 55.879999999999995)
# (u'Mind Twist', 55.84)
# (u'Phyrexian Metamorph', 55.81)
# (u'Manglehorn', 55.81)
# (u'Goblin Rabblemaster', 55.74)
# (u'Char', 55.559999999999995)
# (u'Mutavault', 55.32)
# (u'Pia and Kiran Nalaar', 55.26)
# (u'Dragonlord Silumgar', 55.26)
# (u'Jace, Memory Adept', 55.169999999999995)
# (u'Ajani Vengeant', 55.169999999999995)
# (u'Elspeth Tirel', 55.169999999999995)
# (u'Harsh Mentor', 55.00000000000001)
# (u'Flames of the Firebrand', 55.00000000000001)
# (u'Mirror Entity', 55.00000000000001)
# (u'Song of the Dryads', 54.900000000000006)
# (u'Lavaclaw Reaches', 54.55)
# (u'Talisman of Unity', 54.55)
# (u'Steam Vents', 54.55)
# (u"Kolaghan's Command", 54.55)
# (u'True-Name Nemesis', 54.55)
# (u'Hangarback Walker', 54.410000000000004)
# (u'Terminate', 54.290000000000006)
# (u'Release the Gremlins', 54.290000000000006)
# (u'Keldon Marauders', 54.169999999999995)
# (u'Maelstrom Pulse', 54.169999999999995)
# (u"Sensei's Divining Top", 54.169999999999995)
# (u'Goblin Glory Chaser', 54.169999999999995)
# (u'Fyndhorn Elves', 54.0)
# (u'Skinrender', 53.849999999999994)
# (u'Dreadbore', 53.849999999999994)
# (u'Damnation', 53.849999999999994)
# (u'Karn Liberated', 53.849999999999994)
# (u'Firebolt', 53.849999999999994)
# (u'Recurring Nightmare', 53.66)
# (u'Grafted Wargear', 53.56999999999999)
# (u'Ratchet Bomb', 53.33)
# (u'Llanowar Wastes', 53.33)
# (u'Hymn to Tourach', 53.33)
# (u'Grave Titan', 53.33)
# (u'Mana Vault', 53.33)
# (u'Show and Tell', 53.33)
# (u'Inquisition of Kozilek', 53.33)
# (u'Abrupt Decay', 53.33)
# (u'Overgrown Tomb', 53.33)
# (u'Martial Coup', 53.190000000000005)
# (u'Journey to Nowhere', 53.059999999999995)
# (u'Recruiter of the Guard', 53.059999999999995)
# (u'Acidic Slime', 53.059999999999995)
# (u'Nissa, Vastwood Seer', 52.629999999999995)
# (u'Hazoret the Fervent', 52.38)
# (u'Windswept Heath', 52.38)
# (u'Everflowing Chalice', 52.38)
# (u'Twilight Mire', 52.17)
# (u'Woodfall Primus', 52.17)
# (u'Oblivion Ring', 52.080000000000005)
# (u'Polukranos, World Eater', 52.0)
# (u'Triskelion', 51.849999999999994)
# (u'Plow Under', 51.849999999999994)
# (u'Lingering Souls', 51.72)
# (u'Faithless Looting', 51.72)
# (u'Ophiomancer', 51.43)
# (u'Impulse', 51.28)
# (u'Wild Nacatl', 51.160000000000004)
# (u'Skullclamp', 51.019999999999996)
# (u'Gemstone Mine', 50.94)
# (u'Creeping Tar Pit', 50.68)
# (u'Preordain', 50.0)
# (u'Isamaru, Hound of Konda', 50.0)
# (u'Talisman of Dominance', 50.0)
# (u'Entreat the Angels', 50.0)
# (u"Sram's Expertise", 50.0)
# (u'Gnarled Scarhide', 50.0)
# (u'Wooded Bastion', 50.0)
# (u'Armageddon', 50.0)
# (u'Sylvan Advocate', 50.0)
# (u'Garruk Relentless', 50.0)
# (u'Terramorphic Expanse', 50.0)
# (u'Tombstalker', 50.0)
# (u'Savannah Lions', 50.0)
# (u'Seal of Cleansing', 50.0)
# (u'Glen Elendra Archmage', 50.0)
# (u'Primeval Titan', 49.09)
# (u'Thragtusk', 48.89)
# (u'Ruinous Path', 48.89)
# (u'Mimic Vat', 48.78)
# (u'Angel of Invention', 48.57)
# (u'Garruk, Primal Hunter', 48.28)
# (u"Man-o'-War", 48.15)
# (u'Infest', 48.0)
# (u'Viridian Shaman', 47.83)
# (u'Myr Battlesphere', 47.83)
# (u'Nekrataal', 47.83)
# (u'Engineered Explosives', 47.620000000000005)
# (u'Oath of Druids', 47.620000000000005)
# (u'Tooth and Nail', 47.620000000000005)
# (u'Fumigate', 47.620000000000005)
# (u'Sarkhan, the Dragonspeaker', 47.5)
# (u"Kodama's Reach", 47.370000000000005)
# (u'Wall of Roots', 47.370000000000005)
# (u'Bloodstained Mire', 47.22)
# (u'Awakening Zone', 47.06)
# (u'Jungle Lion', 47.06)
# (u'Canyon Slough', 47.06)
# (u'Liliana, Heretical Healer', 46.88)
# (u'Young Pyromancer', 46.67)
# (u'Kytheon, Hero of Akros', 46.43)
# (u'Sword of Body and Mind', 46.339999999999996)
# (u'Hanweir Garrison', 46.339999999999996)
# (u'Flame Slash', 46.339999999999996)
# (u'Lone Missionary', 46.339999999999996)
# (u'Polluted Delta', 46.339999999999996)
# (u'Pithing Needle', 46.300000000000004)
# (u'Concealed Courtyard', 46.150000000000006)
# (u'Rofellos, Llanowar Emissary', 46.150000000000006)
# (u'Wooded Foothills', 45.95)
# (u'Brimaz, King of Oreskos', 45.83)
# (u'Sun Titan', 45.83)
# (u'Hero of Bladehold', 45.45)
# (u'Balance', 45.45)
# (u'Sakura-Tribe Elder', 45.45)
# (u'Consecrated Sphinx', 45.45)
# (u'Winter Orb', 45.45)
# (u'Vampiric Tutor', 45.45)
# (u'Manic Vandal', 45.1)
# (u'Mind Stone', 45.0)
# (u'Elspeth, Knight-Errant', 44.9)
# (u'Llanowar Elves', 44.83)
# (u'Riftwing Cloudskate', 44.83)
# (u'Thrun, the Last Troll', 44.440000000000005)
# (u'Land Tax', 44.440000000000005)
# (u'Mana Tithe', 44.440000000000005)
# (u'Lightning Strike', 44.440000000000005)
# (u'Greater Gargadon', 44.440000000000005)
# (u'Parallax Wave', 44.440000000000005)
# (u'Arc Lightning', 44.440000000000005)
# (u'Rakdos Cackler', 44.440000000000005)
# (u'Path to Exile', 44.12)
# (u'Duress', 44.0)
# (u'Scattered Groves', 43.9)
# (u'Counterspell', 43.9)
# (u'Birds of Paradise', 43.75)
# (u'Ajani Goldmane', 43.75)
# (u'Powder Keg', 43.59)
# (u'Fauna Shaman', 42.86)
# (u'Stoneforge Mystic', 42.86)
# (u'Mother of Runes', 42.86)
# (u'Uktabi Orangutan', 42.86)
# (u'Custodi Lich', 42.86)
# (u'Imposing Sovereign', 42.86)
# (u'Dryad Militant', 42.86)
# (u'Treasure Cruise', 42.86)
# (u'Thraben Inspector', 42.86)
# (u"Green Sun's Zenith", 42.86)
# (u'Watery Grave', 42.86)
# (u'Aerial Responder', 42.86)
# (u'Magma Jet', 42.5)
# (u'Mana Leak', 42.5)
# (u'Phyrexian Arena', 42.42)
# (u'Wall of Omens', 42.42)
# (u'Inkwell Leviathan', 42.309999999999995)
# (u'Godless Shrine', 42.309999999999995)
# (u'Vindicate', 42.309999999999995)
# (u'Asylum Visitor', 42.11)
# (u'Demonic Tutor', 41.67)
# (u'Master of the Wild Hunt', 41.67)
# (u'Regrowth', 41.67)
# (u'Scavenging Ooze', 41.38)
# (u'Go for the Throat', 41.3)
# (u'Basalt Monolith', 41.18)
# (u'Blade Splicer', 41.07)
# (u'Mardu Strike Leader', 40.910000000000004)
# (u'Curse of Predation', 40.910000000000004)
# (u'Prowling Serpopard', 40.910000000000004)
# (u'Worldly Tutor', 40.739999999999995)
# (u'Flickerwisp', 40.739999999999995)
# (u"Mirari's Wake", 40.739999999999995)
# (u'Enlightened Tutor', 40.739999999999995)
# (u'Survival of the Fittest', 40.739999999999995)
# (u'Kitchen Finks', 40.739999999999995)
# (u'Fire // Ice', 40.63)
# (u'Vampire Nighthawk', 40.0)
# (u'Thoughtseize', 40.0)
# (u'Treetop Village', 40.0)
# (u'Dread Wanderer', 40.0)
# (u'Plated Geopede', 40.0)
# (u'Soldier of the Pantheon', 40.0)
# (u'Sorin, Lord of Innistrad', 39.129999999999995)
# (u'Sword of Fire and Ice', 39.129999999999995)
# (u'Steppe Lynx', 38.71)
# (u'Jace Beleren', 38.24)
# (u'Mana Confluence', 38.1)
# (u'Incinerate', 37.93)
# (u'Spear of Heliod', 37.93)
# (u'Coalition Relic', 37.5)
# (u'Kozilek, Butcher of Truth', 37.14)
# (u'Memory Lapse', 37.14)
# (u"Hero's Downfall", 37.04)
# (u'Languish', 36.84)
# (u'Disenchant', 36.84)
# (u'Yavimaya Elder', 36.36)
# (u'Wall of Blossoms', 36.36)
# (u'Bonesplitter', 36.36)
# (u'Solemn Simulacrum', 36.36)
# (u'Bloodghast', 36.0)
# (u'Bane of the Living', 36.0)
# (u'Banishing Light', 35.709999999999994)
# (u'Firedrinker Satyr', 35.14)
# (u'Shambling Vent', 35.0)
# (u'Sol Ring', 35.0)
# (u'Golgari Signet', 35.0)
# (u'Dark Ritual', 35.0)
# (u'Exalted Angel', 35.0)
# (u'Zurgo Bellstriker', 34.78)
# (u'Brainstorm', 34.78)
# (u'Enclave Cryptologist', 34.78)
# (u'Deep Analysis', 34.78)
# (u'Serum Visions', 34.38)
# (u'Thalia, Guardian of Thraben', 33.33)
# (u'Irrigated Farmland', 33.33)
# (u'Geist of Saint Traft', 33.33)
# (u'Eternal Dragon', 33.33)
# (u'Flesh Carver', 32.0)
# (u'Swords to Plowshares', 31.71)
# (u'Masticore', 31.03)
# (u'Vampire Hexmage', 30.0)
# (u'Hellspark Elemental', 30.0)
# (u'Student of Warfare', 28.57)
# (u'Kor Skyfisher', 28.57)
# (u'Secure the Wastes', 28.57)
# (u"Volrath's Stronghold", 28.13)
# (u'Accorder Paladin', 28.000000000000004)
# (u'Icy Manipulator', 27.66)
# (u'Reveillark', 26.919999999999998)
# (u'Catastrophe', 26.32)
# (u'Sulfur Falls', 25.0)
# (u'Firestorm', 22.58)
# (u'Maze of Ith', 22.220000000000002)
# (u'Shelldock Isle', 22.220000000000002)
# (u'Grim Lavamancer', 21.740000000000002)
# (u"Yahenni's Expertise", 20.0)
# (u'Wurmcoil Engine', 20.0)
# (u'Lodestone Golem', 15.790000000000001)

# %%
# Preparing graphs for statistics

import graphviz as gv

import functools
graph = functools.partial(gv.Graph, format='svg')
digraph = functools.partial(gv.Digraph, format='svg')

def add_nodes(graph, nodes):
    for n in nodes:
        if isinstance(n, tuple):
            graph.node(n[0], **n[1])
        else:
            graph.node(n)
    return graph

def add_edges(graph, edges):
    for e in edges:
        if isinstance(e[0], tuple):
            graph.edge(*e[0], **e[1])
        else:
            graph.edge(*e)
    return graph

def apply_styles(graph, styles):
    graph.graph_attr.update(
        ('graph' in styles and styles['graph']) or {}
    )
    graph.node_attr.update(
        ('nodes' in styles and styles['nodes']) or {}
    )
    graph.edge_attr.update(
        ('edges' in styles and styles['edges']) or {}
    )
    return graph

styles = {
    'graph': {
        'label': 'Players and games',
        'fontsize': '16',
        'fontcolor': 'yellow',
        'bgcolor': '#333333',
        'rankdir': 'TB',
    },
    'nodes': {
        'fontname': 'Helvetica',
        'shape': 'oval',
        'fontcolor': 'white',
        'color': 'white',
        'style': 'filled',
        'fillcolor': '#006699',
    },
    'edges': {
        'style': 'solid',
        'color': 'white',
        'arrowhead': 'open',
        'fontname': 'Courier',
        'fontsize': '12',
        'fontcolor': 'white',
    },
}

# %%
# Get graph for archetypes

# Translate matches to archetypes

styles = {
    'graph': {
        'label': 'Archetypes and games',
        'fontsize': '16',
        'fontcolor': 'yellow',
        'bgcolor': '#333333',
        'rankdir': 'TB',
    },
    'nodes': {
        'fontname': 'Helvetica',
        'shape': 'oval',
        'fontcolor': 'blue',
        'color': 'white',
        'style': 'filled',
        'fillcolor': '#006699',
    },
    'edges': {
        'style': 'solid',
        'color': 'white',
        'arrowhead': 'open',
        'fontname': 'Courier',
        'fontsize': '12',
        'fontcolor': 'white',
    },
}

def getPlayerArchetypeDict(draft_data):
    player_archetype = {}
    players = draft_data['player']
    decknames = draft_data['name']
    for i in range(0, len(players)):
        tmp = decknames[i].split(' ')
        player_archetype[players[i]] = tmp[1]
        
    return player_archetype

def convertMatchesPlayerToArchetypes(match_data, player_archetype):
    arch_matches = []
    matches = match_data['matches']
    for i in matches:
        arch1 = player_archetype[i[0]['player']]
        arch2 = player_archetype[i[1]['player']]
        arch_matches.append([{'player': arch1, 'score': i[0]['score']}, {'player': arch2, 'score':i[1]['score']}])
    return arch_matches

def getMatchesAsArchetypesForYear(yy, number_of_drafts):
    archetype_matches = []
    for i in range(1, number_of_drafts+1):
        filename_matches = 'matches_'+str(yy)+'_'+str(i)+'.json'
        filename_decks = 'decklists_'+str(yy)+'_'+str(i)+'.json'
        tmp_deck = loadDrafts(filename_decks)
        tmp_matches = loadMatchData(filename_matches)
        player_archetype = getPlayerArchetypeDict(tmp_deck)
        arch_matches = convertMatchesPlayerToArchetypes(tmp_matches, player_archetype)
        for j in arch_matches:
            archetype_matches.append(j)
    return archetype_matches

def generateGraphWeightedEdges(all_matches, mode):
    players = extract_players(all_matches)

    player_nodes = []
    for i in players:
        player_nodes.append((i, {'label': i, 'shape': 'oval', 'fillcolor': 'lightgreen'}))

    edges_library = {}
    
    if mode =='games':
        for i in all_matches:
            for j in range(0, i[0]['score']):
                key = i[1]['player'] +' ' +i[0]['player']
                if edges_library.has_key(key):
                    edges_library[key] +=1
                else:
                    edges_library[key] =1
            for j in range(0, i[1]['score']):
                key = i[0]['player'] +' ' +i[1]['player']
                if edges_library.has_key(key):
                    edges_library[key] +=1
                else:
                    edges_library[key] =1   
    
    if mode == 'matches':
        for i in all_matches:      
            if i[0]['score'] > i[1]['score']:
                key = i[1]['player'] +' ' +i[0]['player']
            else:
                key = i[0]['player'] +' ' +i[1]['player']
            if edges_library.has_key(key):
                edges_library[key] +=1
            else:
                edges_library[key] =1

    weighted_edges = []
    for i in edges_library:
        tmp = i.split(' ')
        tmp = (tmp[0], tmp[1])

        weight = str(edges_library[i])
        wlib = { 'label': weight, 'color': 'lightblue'}
        weighted_edges.append((tmp, wlib))
    
    games_graph = add_edges(add_nodes(digraph(), player_nodes), weighted_edges)

    games_graph = apply_styles(games_graph, styles)

    games_graph.render('img/'+mode+'_archetypes_weighted')

#all_matches = loadAllMatchesFromYear(8, 17)

      
archetype_matches = getMatchesAsArchetypesForYear(17, 8)

generateGraphWeightedEdges(archetype_matches, 'games')

# %%
# Get graph for colors

# Translate matches to colors

styles = {
    'graph': {
        'label': 'Colors and matches',
        'fontsize': '16',
        'fontcolor': 'purple',
        'bgcolor': '#333333',
        'rankdir': 'TB',
    },
    'nodes': {
        'fontname': 'Helvetica',
        'shape': 'oval',
        'fontcolor': 'blue',
        'color': 'white',
        'style': 'filled',
        'fillcolor': '#006699',
    },
    'edges': {
        'style': 'solid',
        'color': 'white',
        'arrowhead': 'open',
        'fontname': 'Courier',
        'fontsize': '12',
        'fontcolor': 'white',
    },
}

def getPlayerColorDict(draft_data):
    player_color = {}
    players = draft_data['player']
    decknames = draft_data['name']
    for i in range(0, len(players)):
        tmp = decknames[i].split(' ')
        player_color[players[i]] = tmp[0]
        
    return player_color

def convertMatchesPlayerToColors(match_data, player_color):
    color_matches = []
    matches = match_data['matches']
    for i in matches:
        color1 = player_color[i[0]['player']]
        color2 = player_color[i[1]['player']]
        color_matches.append([{'player': color1, 'score': i[0]['score']}, {'player': color2, 'score':i[1]['score']}])
    return color_matches

def getMatchesAsColorsForYear(yy, number_of_drafts):
    color_matches = []
    for i in range(1, number_of_drafts+1):
        filename_matches = 'matches_'+str(yy)+'_'+str(i)+'.json'
        filename_decks = 'decklists_'+str(yy)+'_'+str(i)+'.json'
        tmp_deck = loadDrafts(filename_decks)
        tmp_matches = loadMatchData(filename_matches)
        player_color = getPlayerColorDict(tmp_deck)
        col_matches = convertMatchesPlayerToColors(tmp_matches, player_color)
        for j in col_matches:
            color_matches.append(j)
    return color_matches

def generateGraphWeightedEdges(all_matches, mode):
    players = extract_players(all_matches)

    player_nodes = []
    for i in players:
        player_nodes.append((i, {'label': i, 'shape': 'oval', 'fillcolor': 'lightgreen'}))

    edges_library = {}
    
    if mode =='games':
        for i in all_matches:
            for j in range(0, i[0]['score']):
                key = i[1]['player'] +' ' +i[0]['player']
                if edges_library.has_key(key):
                    edges_library[key] +=1
                else:
                    edges_library[key] =1
            for j in range(0, i[1]['score']):
                key = i[0]['player'] +' ' +i[1]['player']
                if edges_library.has_key(key):
                    edges_library[key] +=1
                else:
                    edges_library[key] =1   
    
    if mode == 'matches':
        for i in all_matches:      
            if i[0]['score'] > i[1]['score']:
                key = i[1]['player'] +' ' +i[0]['player']
            else:
                key = i[0]['player'] +' ' +i[1]['player']
            if edges_library.has_key(key):
                edges_library[key] +=1
            else:
                edges_library[key] =1

    weighted_edges = []
    for i in edges_library:
        tmp = i.split(' ')
        tmp = (tmp[0], tmp[1])

        weight = str(edges_library[i])
        wlib = { 'label': weight, 'color': 'lightblue'}
        weighted_edges.append((tmp, wlib))
    
    games_graph = add_edges(add_nodes(digraph(), player_nodes), weighted_edges)

    games_graph = apply_styles(games_graph, styles)

    games_graph.render('img/'+mode+'_colors_weighted')

#all_matches = loadAllMatchesFromYear(8, 17)

      
color_matches = getMatchesAsColorsForYear(17, 8)

#generateGraphWeightedEdges(color_matches, 'matches')

# %%
# Use score calculator for the results:

import operator

# input: a set of data with match results
# output: a table with final standings

def extract_players(my_matches):
    players = []
    for i in my_matches:
        players.append(i[0]["player"])
        players.append(i[1]["player"])
    return list(set(players))

def normalized_score(player_score):
    deals = player_score["won"] + player_score["lost"]
    win_rate =(player_score["won"]+0.0)/deals
    return player_score["points"]*100 + round(win_rate *100, 0)

def get_sorted_list(players, player_points):
    standings = {}
    for i in players:
        score = normalized_score(player_points[i])
        standings[i] = score
    sorted_standings = sorted(standings.items(), key=operator.itemgetter(1), reverse=True)

    return sorted_standings

# Loading matches from .json file

def loadMatches(filename):
    matches = pd.read_json('data/matches/'+filename)
    match_data = []
    for i in matches["matches"]: 
        record = []
        record.append({"player": i[0]["player"], "score": i[0]["score"]})
        record.append({"player": i[1]["player"], "score": i[1]["score"]})
        match_data.append(record)
    return match_data

# Calculates score for given set of matches

def calculateScores(match_data):
    players = extract_players(match_data)

    player_points = {}
    for i in players:
        player_points[i] = {"points": 0, "won": 0, "lost": 0}

    for i in players:
        for j in match_data:
            if j[0]["player"] == i:
                player_points[i]["won"] +=j[0]["score"]
                if j[0]["score"] > j[1]["score"]:
                    player_points[i]["points"] += 3
                player_points[i]["lost"] +=j[1]["score"]
            if j[1]["player"] == i:
                player_points[i]["won"] +=j[1]["score"]
                if j[1]["score"] > j[0]["score"]:
                    player_points[i]["points"] += 3
                player_points[i]["lost"] +=j[0]["score"]
    
    standings = get_sorted_list(players, player_points)

    for i in standings:
        won =  player_points[i[0]]['won']
        lost =  player_points[i[0]]['lost']
        win_rate = round((won+0.0)/(won+lost), 2)
        if (won+lost) >= 15:
            print i[0], win_rate
    
    #return standings, player_points

calculateScores(color_matches)

print '   '

calculateScores(archetype_matches)
# Out:
# WG 0.48
# BG 0.61
# UB 0.61
# WR 0.56
# BR 0.54
# UR 0.52
# UW 0.6
# Naya 0.48
# WB 0.31
# Grixis 0.43
#
# Aggro 0.5
# Mid-Range 0.5
# Control 0.52
# Ramp 0.48
